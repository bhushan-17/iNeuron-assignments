# %% [markdown]
# ques.1

# %%
n=int(input())
for i in range(0,n):
    if(i<n/2):
        for j in range(0,i+1):
            print("* ", end="")
        print("\r")
    else:
        for j in range(0,n-i):
            print("* ",end="")
        print("\r")
# Out:
# 9
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ques.2

# %%
str1=str(input(""))
print(str1[::-1])
# Out:
# ineuron
# norueni
