# %%
ques1.1

# %% [markdown]
# ques1.1

# %%
class poly:
    def _init_(self,a,b,c):
        self.a = float(a)
        self.b = float(b)
        self.c = float(c)
a= input("a=")
b= input("b=")
c= input("c=")

class triangle(poly):
    def get_area(self):
        s = (a + b + c) / 2
        return (s*(s-a)*(s-b)*(s-c)) ** 0.5        

t = triangle()
print("area : {}".format(()))
# Out:
# a=2
# b=3
# c=4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8f475bc33150> in <module>()
#      14
#      15 t = triangle()
# ---> 16 print("area : {}".format(get_area()))
#
# NameError: name 'get_area' is not defined

# %% [markdown]
# ques1.2

# %%
def filter_long_word(string,number):

    for i in range(len(string)):
        listwords = []
        if len(string[i]) > number:
            listwords.append(string[i])

        return listwords 


def main():
    words = input("Please input the list of words: ")
    integer = eval(input("Please input an integer: "))

    words1 = filter_long_word(words,integer)

    print("The list of words greater than the integer is",words1)

main()
# Out:
# Please input the list of words: krishna
# Please input an integer: 3
# The list of words greater than the integer is []

# %% [markdown]
# ques2.1

# %%
listOfWords = ['ram','tri','ilove','immad']
 
listOfInts = []
 
for i in range(len(listOfWords)):
    listOfInts.append(len(listOfWords[i]))
 
print ("List of words:"+str(listOfWords))    
print ("List of wordlength:"+str(listOfInts))
# Out:
# List of words:['ram', 'tri', 'ilove', 'immad']
# List of wordlength:[3, 3, 5, 5]

# %%
ques2.2

# %%
inputChar=str(input())
if(len(inputChar)==1):
    if (inputChar == "a" or inputChar == "A" or
        inputChar == "e" or inputChar == "E" or
        inputChar == "i" or inputChar == "I" or
        inputChar == "o" or inputChar == "O" or
        inputChar == "u" or inputChar == "U"):
      print("True")
    else:
      print("False")
else:
 print("please enter single character")
# Out:
# y
# False

# %%
""
