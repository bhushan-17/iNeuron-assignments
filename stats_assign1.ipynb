# %% [markdown]
# Calculate the mean, median, mode and standard deviation for the problem
# statements 1& 2.
# Problem Statement 1:
# The marks awarded for an assignment set for a Year 8 class of 20 students were as
# follows:
# 6 7 5 7 7 8 7 6 9 7 4 10 6 8 8 9 5 6 4 8

# %%
data=[6,7,5,7,7,8,7,6,9,7,4,10,6,8,8,9,5,6,4,8]
df=pd.DataFrame(data)

# %%
import numpy as np
import pandas as pd

# %%
df.mean()
# Out:
# 0    6.85
# dtype: float64

# %%
df.mode()
# Out:
#    0
# 0  7

# %%
df.median()
# Out:
# 0    7.0
# dtype: float64

# %%
df.std()
# Out:
# 0    1.631112
# dtype: float64

# %% [markdown]
# Problem Statement 2:
# The number of calls from motorists per day for roadside service was recorded for a
# particular month:
# 28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170,
# 100, 75, 104, 97, 75,
# 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109

# %%
data1=[28, 122, 217, 130, 120, 86, 80, 90, 140, 120, 70, 40, 145, 113, 90, 68, 174, 194, 170, 100, 75, 104, 97, 75, 123, 100, 75, 104, 97, 75, 123, 100, 89, 120, 109]
df1=pd.DataFrame(data1)
df1.mean()
# Out:
# 0    107.514286
# dtype: float64

# %%
df1.mode()
# Out:
#     0
# 0  75

# %%
df1.median()
# Out:
# 0    100.0
# dtype: float64

# %%
df1.std()
# Out:
# 0    39.338928
# dtype: float64

# %% [markdown]
# prob.3 The number of times I go to the gym in weekdays, are given below along with its
# associated probability:
# x = 0, 1, 2, 3, 4, 5
# f(x) = 0.09, 0.15, 0.40, 0.25, 0.10, 0.01
# Calculate the mean no. of workouts in a week. Also evaluate the variance involved in
# it.

# %%
 x=[0, 1, 2, 3, 4, 5]
 fx=[0.09, 0.15, 0.40, 0.25, 0.10, 0.01]
 df3=pd.DataFrame(x,fx)

# %%
df3.mean()
# Out:
# 0    2.5
# dtype: float64

# %%
df3.std()
# Out:
# 0    1.870829
# dtype: float64

# %%
df3.var()
# Out:
# 0    3.5
# dtype: float64

# %% [markdown]
# Problem Statement 4:
# Let the continuous random variable D denote the diameter of the hole drilled in an
# aluminum sheet. The target diameter to be achieved is 12.5mm. Random
# disturbances in the process often result in inaccuracy.
# Historical data shows that the distribution of D can be modelled by the PDF (d) =
# 20e−20(d−12.5), d ≥ 12.5. If a part with diameter > 12.6 mm needs to be scrapped,
# what is the proportion of those parts? What is the CDF when the diameter is of 11
# mm? What is your conclusion regarding the proportion of scraps?

# %%
![picture](https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing)'

# %% [markdown]
# Problem Statement 5:
#
# A company manufactures LED bulbs with a faulty rate of 30%. If I randomly select 6
# chosen LEDs, what is the probability of having 2 faulty LEDs in my sample?
# Calculate the average value of this process. Also evaluate the standard deviation
# associated with it.

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
binomial_data=binom.rvs(n=6,p=0.3,size=1000)
sns.distplot(binomial_data,hist=True,kde=True,color="red")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Probability of getting faulty out of 6 trials
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=2,n=6,p=0.3)
print("Probability will be :",probab)
cdf=binom.cdf(k=2,n=6,p=0.3)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.32413499999999995
# CDF will be : 0.74431

# %%
import scipy.stats as binom
import math 
mean,var=binom.stats(n=6,p=0.3)
print("mean := ",mean)
print("standard deviation :=",math.sqrt(var))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ab013ae67a5b> in <module>()
#       1 import scipy.stats as binom
#       2 import math
# ----> 3 mean,var=binom.stats(n=6,p=0.3)
#       4 print("mean := ",mean)
#       5 print("standard deviation :=",math.sqrt(var))
#
# TypeError: 'module' object is not callable

# %%
![picture](https://drive.google.com/file/d/1MmAV-6gTUgSkVZYXbATub1n6pNDwiKIG/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1MmAV-6gTUgSkVZYXbATub1n6pNDwiKIG/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1MmAV-6gTUgSkVZYXbATub1n6pNDwiKIG/view?usp=sharing)'

# %% [markdown]
# prob. 6:
#
# Gaurav and Barakha are both preparing for entrance exams. Gaurav attempts to
# solve 8 questions per day with a correction rate of 75%, while Barakha averages
# around 12 questions per day with a correction rate of 45%. What is the probability
# that each of them will solve 5 questions correctly? What happens in cases of 4 and 6
# correct solutions? What do you infer from it? What are the two main governing
# factors affecting their ability to solve questions correctly? Give a pictorial
# representation of the same to validate your answer.

# %%
![picture](https://drive.google.com/file/d/1cCcjnLPLsdWjL-Lqctt-az8kHXuqsRgy/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1cCcjnLPLsdWjL-Lqctt-az8kHXuqsRgy/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1cCcjnLPLsdWjL-Lqctt-az8kHXuqsRgy/view?usp=sharing)'

# %%
#for boy
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
binomial_data=binom.rvs(n=8,p=0.75,size=1000)
sns.distplot(binomial_data,hist=True,kde=True,color="red")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#for boy at x=4 
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=4,n=8,p=0.75)
print("Probability will be :",probab)
cdf=binom.cdf(k=4,n=8,p=0.75)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.08651733398437506
# CDF will be : 0.11381530761718749

# %%
#for boy at x=6
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=6,n=8,p=0.75)
print("Probability will be :",probab)
cdf=binom.cdf(k=6,n=8,p=0.75)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.31146240234375017
# CDF will be : 0.6329193115234373

# %%
#for girl
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
binomial_data=binom.rvs(n=12,p=0.45,size=1000)
sns.distplot(binomial_data,hist=True,kde=True,color="yellow")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#for girl at x=4
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=4,n=12,p=0.45)
print("Probability will be :",probab)
cdf=binom.cdf(k=4,n=12,p=0.45)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.1699639321360581
# CDF will be : 0.3044320013260573

# %%
# for girls at x=6
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns
probab=binom.pmf(k=6,n=12,p=0.45)
print("Probability will be :",probab)
cdf=binom.cdf(k=6,n=12,p=0.45)
print("CDF will be :",cdf)
# Out:
# Probability will be : 0.21238468214026432
# CDF will be : 0.7393149218989801

# %% [markdown]
# Problem Statement 7:
#
# Customers arrive at a rate of 72 per hour to my shop. What is the probability of k
# customers arriving in 4 minutes? a) 5 customers, b) not more than 3 customers, c)
# more than 3 customers. Give a pictorial representation of the same to validate your
# answer.[link text](https:// [link text](https://))

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
import seaborn as sns
poisson_data=poisson.rvs(mu=4.8,size=1000)
sns.distplot(poisson_data,hist=True,kde=True,color="red")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import poisson
probab1=poisson.pmf(k=5,mu=4.8)
probab2=sum(poisson.pmf(k=[0,1,2],mu=4.8))
print(probab1,probab2)
# Out:
# 0.17474768364388296 0.14253921888902693

# %%
![picture](https://drive.google.com/file/d/1cBG90cnJq7-75vqcfeR4nGL-S9ROei9p/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1cBG90cnJq7-75vqcfeR4nGL-S9ROei9p/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1cBG90cnJq7-75vqcfeR4nGL-S9ROei9p/view?usp=sharing)'

# %% [markdown]
# Problem Statement 9:
#
# Let the continuous random variable D denote the diameter of the hole drilled in an
# aluminum sheet. The target diameter to be achieved is 12.5mm. Random
# disturbances in the process often result in inaccuracy.
# Historical data shows that the distribution of D can be modelled by the PDF, f(d) =
# 20e−20(d−12.5), d ≥ 12.5. If a part with diameter > 12.6 mm needs to be scrapped,
# what is the proportion of those parts? What is the CDF when the diameter is of 11
# mm?
# What is the conclusion of this experiment?

# %%
![picture](https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1MW35ScR8nR0v-PRiIF7XwE2P8ezJlHLM/view?usp=sharing)'

# %% [markdown]
# Problem Statement 10:
#
# Please compute the following:
# a) P(Z > 1.26), . P(Z < −0.86), P(Z > −1.37), P(−1.25 < Z < 0.37), . P(Z ≤ −4.6)
# b) Find the value z such that P(Z > z) = 0.05
# c) Find the value of z such that P(−z < Z < z) = 0.99

# %%
#a
#P(Z>1.26)
k=1-0.89617
k
# Out:
# 0.10382999999999998

# %%
#P(Z<-0.86)
k=0.19489
k
# Out:
# 0.19489

# %%
#P(Z>-1.37)
k=1-0.08534
k
# Out:
# 0.91466

# %%
#P(-1.25<Z<0.37)
k=0.6443-0.1056
k
# Out:
# 0.5387

# %%
#P(Z<=-4.6)
k=~0.0001

# %%
#b
#P(Z>z)=0.05
z=-1.64

# %%
#c
#P(-z<Z<z)=0.99
z=2.57

# %%
![picture](https://drive.google.com/file/d/1cHmJYBpH7fOQruUG-R2lDdO_ynUyHnCS/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1cHmJYBpH7fOQruUG-R2lDdO_ynUyHnCS/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1cHmJYBpH7fOQruUG-R2lDdO_ynUyHnCS/view?usp=sharing)'

# %% [markdown]
# Problem Statement 11:
#
# The current flow in a copper wire follow a normal distribution with a mean of 10 mA
# and a variance of 4 (mA)2.
# What is the probability that a current measurement will exceed 13 mA? What is the
# probability that a current measurement is between 9 and 11mA? Determine the
# current measurement which has a probability of 0.98.

# %%
![picture](https://drive.google.com/file/d/1cONOtHkpsNVsK_f5Uapupapzkf0kAxXZ/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1cONOtHkpsNVsK_f5Uapupapzkf0kAxXZ/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1cONOtHkpsNVsK_f5Uapupapzkf0kAxXZ/view?usp=sharing)'

# %% [markdown]
# Problem Statement 12:
#
# The shaft in a piston has its diameter normally distributed with a mean of 0.2508 inch
# and a standard deviation of 0.0005 inch. The specifications of the shaft are 0.2500 ∓
# 0.0015 inch. What proportion of shafts are in sync with the specifications? If the
# process is centered so that the mean is equal to the target value of 0.2500, what
# proportion of shafts conform to the new specifications? What is your conclusion from
# this experiment?

# %%
![picture](https://drive.google.com/file/d/1cWOSV8DswE0xYYDR2iDfx70DcqrL6RN7/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1cWOSV8DswE0xYYDR2iDfx70DcqrL6RN7/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1cWOSV8DswE0xYYDR2iDfx70DcqrL6RN7/view?usp=sharing)'
